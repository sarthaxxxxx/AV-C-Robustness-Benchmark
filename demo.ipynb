# %%
from avc2_dataset import AV2C
from PIL import Image
from IPython.display import display, Audio
import io

# %%
file_path = '/home/adrian/Data/AudioSet/eval.json'

# %%
clean_dataset = AV2C(file_path, corruption=None)
clean_image, clean_audio = clean_dataset[0]
display(clean_image)
Audio(clean_audio.read(), autoplay=False)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=224x224>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gaussian_dataset = AV2C(file_path, corruption='gaussian', severity=5)
gaussian_image, gaussian_audio = gaussian_dataset[0]
display(gaussian_image)
Audio(gaussian_audio.read(), autoplay=False)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
gaussian_dataset = AV2C(file_path, corruption='gaussian', severity=2)
gaussian_image, gaussian_audio = gaussian_dataset[0]
display(gaussian_image)
Audio(gaussian_audio.read(), autoplay=False)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
snow_dataset = AV2C(file_path, corruption='snow', severity=5)
snow_image, snow_audio = snow_dataset[0]
display(snow_image)
Audio(snow_audio.read(), autoplay=False)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
